# %%
#IMPORTS

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.naive_bayes import GaussianNB

import scikitplot as skplt
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import roc_auc_score,roc_curve,f1_score,recall_score,precision_score

# %%
train = pd.read_csv('Downloads/train_LZdllcl.csv')
test = pd.read_csv('Downloads/test_2umaH9m.csv')

# %%
train.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
train.drop('employee_id',inplace=True,axis=1
          )

# %%
for i in train.columns:
    print(train[i].value_counts())
# Out:
# Sales & Marketing    16840
# Operations           11348
# Procurement           7138
# Technology            7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: department, dtype: int64
# region_2     12343
# region_22     6428
# region_7      4843
# region_15     2808
# region_13     2648
# region_26     2260
# region_31     1935
# region_4      1703
# region_27     1659
# region_16     1465
# region_28     1318
# region_11     1315
# region_23     1175
# region_29      994
# region_32      945
# region_19      874
# region_20      850
# region_14      827
# region_25      819
# region_17      796
# region_5       766
# region_6       690
# region_30      657
# region_8       655
# region_10      648
# region_1       610
# region_24      508
# region_12      500
# region_9       420
# region_21      411
# region_3       346
# region_34      292
# region_33      269
# ...

# %%
sb.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.describe()
# Out:
#        no_of_trainings           age  previous_year_rating  length_of_service  \
# count     54808.000000  54808.000000          50684.000000       54808.000000
# mean          1.253011     34.803915              3.329256           5.865512
# std           0.609264      7.660169              1.259993           4.265094
# min           1.000000     20.000000              1.000000           1.000000
# 25%           1.000000     29.000000              3.000000           3.000000
# 50%           1.000000     33.000000              3.000000           5.000000
# 75%           1.000000     39.000000              4.000000           7.000000
# max          10.000000     60.000000              5.000000          37.000000
#
#        KPIs_met >80%   awards_won?  avg_training_score   is_promoted
# count   54808.000000  54808.000000        54808.000000  54808.000000
# mean        0.351974      0.023172           63.386750      0.085170
# ...

# %%
sb.countplot(train['is_promoted'])
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='count'>

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
x = train.drop('is_promoted',axis=1)
y = train['is_promoted']

# %%
x_over,y_over = RandomOverSampler().fit_resample(x,y)

# %%
sb.countplot(y_over)
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='count'>

# %%
c=1
plt.figure(figsize=(16,20))
for i in ['department','education','gender','recruitment_channel','no_of_trainings',
          'previous_year_rating','KPIs_met >80%','awards_won?']:
    
    
    plt.subplot(3,3,c)
   
    ax = sb.countplot(x_over[i],hue=y_over)
    plt.xticks(rotation=90)
    total = len(x_over)
    for p in ax.patches:
        percentage = f'{100 * p.get_height() / total:.1f}%\n'
        x = p.get_x() + p.get_width() / 2
        y = p.get_height()
        ax.annotate(percentage, (x, y), ha='center', va='center')
#plt.tight_layout()
    
    c=c+1
    plt.tight_layout()

# %% [markdown]
# ###### OBSERVATIONS
#         - Awards_won influences the is_promated target variable, as employees with awards won has more than 90% probability to be Promoted.
#         - KPIs met>80 has higher probability to belong in is_pormoted. where as kpi_mets<80 has higher probability to belong in no promotion.
#         - previous year rating has corelation with promotion rate, as previous year rating vlaue increases, probability of promotion also increses, as of low value to previous_year belongs to no promotion.
#         -other feature donot show much co relation

# %%
c=1
plt.figure(figsize=(10,8))
for i in ['age','avg_training_score','length_of_service']:
    
    
    plt.subplot(2,2,c)
   
    sb.distplot(x_over[i])
    plt.legend([str(train[i].skew())])
   
    
    c=c+1
    plt.tight_layout()

# %%
c=1
plt.figure(figsize=(10,8))
for i in ['age','avg_training_score','length_of_service']:
    
    
    plt.subplot(2,2,c)
   
    sb.barplot(y_over,x_over[i])

   
    
    c=c+1
    plt.tight_layout()

# %% [markdown]
# #### average training score of is_promoted is higher than not_promoted.

# %%
train
# Out:
#               department     region         education gender  \
# 0      Sales & Marketing   region_7  Master's & above      f
# 1             Operations  region_22        Bachelor's      m
# 2      Sales & Marketing  region_19        Bachelor's      m
# 3      Sales & Marketing  region_23        Bachelor's      m
# 4             Technology  region_26        Bachelor's      m
# ...                  ...        ...               ...    ...
# 54803         Technology  region_14        Bachelor's      m
# 54804         Operations  region_27  Master's & above      f
# 54805          Analytics   region_1        Bachelor's      m
# 54806  Sales & Marketing   region_9               NaN      m
# 54807                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
(train.isnull()).sum(axis=0)
# Out:
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
train.shape
# Out:
# (54808, 13)

# %%
train = train.dropna()

# %%
train.shape
# Out:
# (48660, 13)

# %%
train.skew()
# Out:
# no_of_trainings         3.409642
# age                     1.004034
# previous_year_rating   -0.315554
# length_of_service       1.810363
# KPIs_met >80%           0.599347
# awards_won?             6.343586
# avg_training_score      0.428738
# is_promoted             2.931535
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer, StandardScaler

# %%
train.head(2)
# Out:
#    department  region  education  gender  recruitment_channel  \
# 0           7      31          2       0                    2
# 1           4      14          0       1                    0
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
#
#    KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# 0              1            0           -1.100196            0
# 1              0            0           -0.271469            0

# %%
test['education'] = test['education'].fillna(test['education'].mode()[0])
test['previous_year_rating'] = test['previous_year_rating'].fillna(test['previous_year_rating'].mode()[0])

# %%
train['department'] = LabelEncoder().fit_transform(train['department'])

train['region'] = LabelEncoder().fit_transform(train['region'])

train['education'] = LabelEncoder().fit_transform(train['education'])


train['recruitment_channel'] = LabelEncoder().fit_transform(train['recruitment_channel'])

train['gender'] = LabelEncoder().fit_transform(train['gender'])


test['department'] = LabelEncoder().fit_transform(test['department'])

test['region'] = LabelEncoder().fit_transform(test['region'])

test['education'] = LabelEncoder().fit_transform(test['education'])


test['recruitment_channel'] = LabelEncoder().fit_transform(test['recruitment_channel'])

test['gender'] = LabelEncoder().fit_transform(test['gender'])

# %%
plt.figure(figsize=(12,9))
sb.heatmap(train.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
x = train.drop(['age','is_promoted'],axis=1)

test.drop('age',inplace=True,axis=1)
y = train['is_promoted']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-213-f81a0052ab74> in <module>
#       1 x = train.drop(['age','is_promoted'],axis=1)
#       2
# ----> 3 test.drop('age',inplace=True,axis=1)
#       4 y = train['is_promoted']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(x.values, i)
                          for i in range(len(x.columns))]
vif_data
# Out:
#                  feature        VIF
# 0             department   4.228582
# 1                 region   3.832944
# 2              education   1.521906
# 3                 gender   3.168310
# 4    recruitment_channel   1.758762
# 5        no_of_trainings   5.015488
# 6   previous_year_rating   8.062920
# 7      length_of_service   3.283841
# 8          KPIs_met >80%   1.813272
# 9            awards_won?   1.038700
# 10    avg_training_score  12.876915

# %%
x['avg_training_score'] = StandardScaler().fit_transform(x[['avg_training_score']])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA().fit(x,y)

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.72871295, 0.8941931 , 0.95258172, 0.96732409, 0.97633433,
#        0.98516766, 0.99262311, 0.99603634, 0.99799175, 0.99979198,
#        1.        ])

# %%
plt.bar(range(1,12),np.cumsum(pca.explained_variance_ratio_))
# Out:
# <BarContainer object of 11 artists>

# %%
pca = PCA(n_components=7)

# %%
features = pca.fit_transform(x,y)

# %%
pca_data = pd.DataFrame(features,columns=range(1,8))

# %%
x_pca,y_pca = RandomOverSampler().fit_resample(pca_data,y)
x_over,y_over = RandomOverSampler().fit_resample(x,y)

# %%
#function to find best random state for any model

randomstate = 0
max_score = 0
model = LGBMClassifier()
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x_over,y_over,test_size=.30,random_state=i)
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    score = f1_score(y_test,pred)    
    if(score>max_score):
        max_score = score
        randomstate  = i
    print(i,score)
# Out:
# 1 0.8624200805114848
# 2 0.8595362141178875
# 3 0.8631770412287795
# 4 0.8633540372670807
# 5 0.8613690858127047
# 6 0.8616122710993985
# 7 0.8607792031953424
# 8 0.8645691764066322
# 9 0.8599401137166504
# 10 0.8608586967537073
# 11 0.8629690048939641
# 12 0.8600464380657536
# 13 0.8648978347057029
# 14 0.8623078222672749
# 15 0.8626616688616487
# 16 0.8618458933107536
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-186-aab7a6bd7f62> in <module>
#       6 for i in range(1,200):
#       7     x_train,x_test,y_train,y_test = train_test_split(x_over,y_over,test_size=.30,random_state=i)
# ----> 8     model.fit(x_train,y_train)
#       9     pred = model.predict(x_test)
#      10     score = f1_score(y_test,pred)
#
# ...

# %%
 x_train,x_test,y_train,y_test = train_test_split(x_over,y_over,test_size=.30,random_state=45)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
pred = model.predict(x_test)
print('Logistic Regression')
print('F1 Score          : ',f1_score(y_test,pred))
print('Accuracy Score    :',accuracy_score(y_test,pred))
train_score = np.mean(cross_val_score(model,x_train,y_train,cv=5))
print('Train Score       : ', train_score)
print(classification_report(y_test,pred))
# Out:
# Logistic Regression
# F1 Score          :  0.7216602590422156
# Accuracy Score    : 0.7202610946468094
# Train Score       :  0.7130661796770814
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72     13332
#            1       0.72      0.73      0.72     13325
#
#     accuracy                           0.72     26657
#    macro avg       0.72      0.72      0.72     26657
# weighted avg       0.72      0.72      0.72     26657

# %%
    pred_proba = model.predict_proba(x_test)[:,1]
    fpr,tpr,threshold = roc_curve(y_test,pred_proba)
    plt.figure(figsize=(8,5))
    plt.plot(fpr,tpr)
    plt.ylabel('Sensitivity')
    plt.xlabel('1 - Specificity')
    leg = 'AUC SCORE:'+ str(roc_auc_score(y_test,pred_proba))
    plt.legend( [leg],loc= 10)
    
    
    plt.figure()
    skplt.metrics.plot_confusion_matrix(y_test,pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
model = LGBMClassifier()
model.fit(x_train,y_train)
pred = model.predict(x_test)
print('Logistic Regression')
print('F1 Score          : ',f1_score(y_test,pred))
print('Accuracy Score    :',accuracy_score(y_test,pred))
train_score = np.mean(cross_val_score(model,x_train,y_train,cv=5))
print('Train Score       : ', train_score)
print(classification_report(y_test,pred))
# Out:
# Logistic Regression
# F1 Score          :  0.8648886482095715
# Accuracy Score    : 0.8502457140713509
# Train Score       :  0.8468142580810433
#               precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83     13332
#            1       0.79      0.96      0.86     13325
#
#     accuracy                           0.85     26657
#    macro avg       0.87      0.85      0.85     26657
# weighted avg       0.87      0.85      0.85     26657

# %%
    pred_proba = model.predict_proba(x_test)[:,1]
    fpr,tpr,threshold = roc_curve(y_test,pred_proba)
    plt.figure(figsize=(8,5))
    plt.plot(fpr,tpr)
    plt.ylabel('Sensitivity')
    plt.xlabel('1 - Specificity')
    leg = 'AUC SCORE:'+ str(roc_auc_score(y_test,pred_proba))
    plt.legend( [leg],loc= 10)
    
    
    plt.figure()
    skplt.metrics.plot_confusion_matrix(y_test,pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred = dtc.predict(x_test)
print('Logistic Regression')
print('F1 Score          : ',f1_score(y_test,pred))
print('Accuracy Score    :',accuracy_score(y_test,pred))
train_score = np.mean(cross_val_score(model,x_train,y_train,cv=5))
print('Train Score       : ', train_score)
print(classification_report(y_test,pred))
# Out:
# Logistic Regression
# F1 Score          :  0.9644861166419288
# Accuracy Score    : 0.9631991596953896
# Train Score       :  0.8468142580810433
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96     13332
#            1       0.93      1.00      0.96     13325
#
#     accuracy                           0.96     26657
#    macro avg       0.97      0.96      0.96     26657
# weighted avg       0.97      0.96      0.96     26657

# %%
    pred_proba = dtc.predict_proba(x_test)[:,1]
    fpr,tpr,threshold = roc_curve(y_test,pred_proba)
    plt.figure(figsize=(8,5))
    plt.plot(fpr,tpr)
    plt.ylabel('Sensitivity')
    plt.xlabel('1 - Specificity')
    leg = 'AUC SCORE:'+ str(roc_auc_score(y_test,pred_proba))
    plt.legend( [leg],loc= 10)
    
    
    plt.figure()
    skplt.metrics.plot_confusion_matrix(y_test,pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# #### Evaluating TEST DATA

# %%
test['avg_training_score'] = StandardScaler().fit_transform(test[['avg_training_score']])

# %%
id = test['employee_id']

# %%
test.drop('employee_id',axis=1,inplace=True)

# %%
test_pred = dtc.predict(test)

# %%
dict = {'employee_id':id,
       'is_promoted':test_pred}

# %%
predictions_hr = pd.DataFrame(dict)

# %%
predictions_hr.to_csv('hr_pred.csv')
